# %%
 # importing libraries
import psycopg2
from sqlalchemy import create_engine
import os 
import pandas as pd 
from psycopg2 import OperationalError
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
 # Connecting to the database 
engine = create_engine(
    f"postgresql+psycopg2://{os.getenv('postgre_account')}:{os.getenv('postgre_password')}@localhost:5432/{os.getenv('database')}"
)

# %%
 # Loading the data 
saved_tracks = pd.read_sql("SELECT * FROM saved_tracks", engine)
playlists = pd.read_sql("SELECT * FROM playlists", engine)
top_artists = pd.read_sql("SELECT * FROM top_artists", engine)
top_tracks = pd.read_sql("SELECT * FROM top_tracks", engine)
recently_played_tracks = pd.read_sql("SELECT * FROM recently_played_tracks", engine)
followed_artists = pd.read_sql("SELECT * FROM followed_artists", engine)
saved_albums = pd.read_sql("SELECT * FROM saved_albums", engine)

# %%
 # Saved_tracks
display(saved_tracks)
print(saved_tracks.columns.to_list())
display(saved_tracks.describe())
display(saved_tracks.describe(include = object).T)
# Out:
#                          id  \
# 0    2J6OF7CkpdQGSfm1wdclqn
# 1    66TTutUCqCpAzGCBcsBuYy
# 2    3EOzLBxti9kA01UvwfbPxs
# 3    1mvDFqbbmgmMmU6U4dIq5m
# 4    2fkeWbM6iqTw7oGHTYm2lw
# ..                      ...
# 520  5rp6f6CiXVjpZ09u0BHeeN
# 521  171PWhxgdrIOgcAiBPO3Gr
# 522  1qHDg5ObxDpRZjoqPQGIyK
# 523  77lKjGkhvWuimTzQxA4STK
# 524  0q6LuUqGLUiCPP1cbdwFs3
#
#                                                   name    artist_name  \
# 0                                              Clouded   Brent Faiyaz
# 1    Waiting In Vain - Bob Marley: One Love - Music...  Daniel Caesar
# 2                                TOO DEEP TO TURN BACK  Daniel Caesar
# 3               Forbidden Fruit (feat. Kendrick Lamar)        J. Cole
# 4                                                 4422          Drake
# ..                                                 ...            ...
# 520                      LET U LEAD (with Billy Lemos)       Noah Guy
# 521                      The Count (feat. Wiz Khalifa)       Curren$y
# 522                                      Sycamore Tree        Khamari
# 523                                        Lovers Rock           Sade
# 524                                 On Melancholy Hill       Gorillaz
#
#                   artist_id  \
# 0    3tlXnStJ1fFhdScmQeLpuG
# 1    20wkVLutqVOYrc0kxFs7rA
# 2    20wkVLutqVOYrc0kxFs7rA
# 3    6l3HvQ5sa6mXTsMTB19rO5
# 4    3TVXtAsR1Inumwj472S9r4
# ..                      ...
# 520  0Cj5PLNNGVOsXUig1ic4s5
# 521  6X8WdFjrNhXATMDSs26aCc
# 522  6kmDosYCYjFQtywDq0DLPZ
# 523  47zz7sob9NUcODy0BTDvKx
# 524  3AA28KZvwAUcZuOKwyblJQ
#
#                                             album_name  \
# 0                                       Fuck The World
# 1    Waiting In Vain (Bob Marley: One Love - Music ...
# 2                                        CASE STUDY 01
# 3                         Born Sinner (Deluxe Version)
# 4                                            More Life
# ..                                                 ...
# 520                      LET U LEAD (with Billy Lemos)
# 521                                         The Marina
# 522                                      Sycamore Tree
# 523                                        Lovers Rock
# 524                                      Plastic Beach
#
#                    album_id  duration  explicit  popularity
# 0    3vi20DRHkqv4HyVg9Rt9wC    110128      True          79
# 1    6ZKGdyXuM5z1nYuCx6YjWP    301466     False          59
# 2    7lb4ck9tn2ZaJRrYjhyP9A    318533      True          65
# 3    5FP9keIJnlSCKnkdVOf623    268666      True          66
# 4    1lXY618HWkwYKJWBRYR4MK    186293     False          69
# ..                      ...       ...       ...         ...
# 520  3qm24mQwYYo7GFGZanPgwc    150857     False          58
# 521  4PBzJyNVh1iWyiuOstR74B    194594      True          63
# 522  43aG2nFhrrTXHXjJR2KoFR    215032     False          64
# 523  0NxA1D1taWpPdIc6uIlAi9    253106     False          69
# 524  2dIGnmEIy1WZIcZCFSj6i8    233866     False          84
#
# [525 rows x 9 columns]
# ['id', 'name', 'artist_name', 'artist_id', 'album_name', 'album_id', 'duration', 'explicit', 'popularity']
#             duration  popularity
# count     525.000000  525.000000
# mean   214086.108571   60.304762
# std     77533.065438   20.844171
# min     34665.000000    0.000000
# 25%    166999.000000   54.000000
# 50%    209490.000000   64.000000
# 75%    248661.000000   74.000000
# max    602296.000000   94.000000
#             count unique                     top freq
# id            525    525  0q6LuUqGLUiCPP1cbdwFs3    1
# name          525    522                    Love    2
# artist_name   525    263                 J. Cole   18
# artist_id     525    263  6l3HvQ5sa6mXTsMTB19rO5   18
# album_name    525    412                Freudian    5
# album_id      525    422  41GuZcammIkupMPKH2OJ6I    5

# %% [markdown]
# From the output we can see that the saved_tracks dataframe has a total of 9 columns

# %%
 # Checking for duplicates and null values
display(saved_tracks.isnull().sum())
display(saved_tracks.nunique())
# Out:
# id             0
# name           0
# artist_name    0
# artist_id      0
# album_name     0
# album_id       0
# duration       0
# explicit       0
# popularity     0
# dtype: int64
# id             525
# name           522
# artist_name    263
# artist_id      263
# album_name     412
# album_id       422
# duration       520
# explicit         2
# popularity      74
# dtype: int64

# %%
 # Playlists
display(playlists)
print(playlists.columns.to_list())
display(playlists.describe())
display(playlists.describe(include = object).T)
# Out:
#                         id                                     name  \
# 0   6Pg4aEjusdmupnIU3lwaTh                         Muhiki Wa Mikosi
# 1   314n8k5HQafloYBSoQpgSJ  Me walking through the school hallways:
# 2   0XyecDuOwJ6WnNOKOPT4p7                       .To be named later
# 3   2FWHYI61XTpVSvhr3BpW79                            Sounds I love
# 4   3drAqyxFs54xxaTA00db26                              Reggae ❤️💛💚
# 5   1AmPdqxo5mLmGlexBAeMVo                        Late Night Drive
# 6   0B5wOBGxLfKrRyAzTRQQKG                               The Lo-Fis
# 7   0M6e4DK9GOw4RRLt1OyK33                                 Thursday
# 8   3yrU7WyL7q3VosfG2BBmbt                          90'S Legends 😎😌
# 9   1UtQp6JF7ZLirT5O6HrzI3                                      🌟🌟🌟
# 10  5w0NeJTpf24MDdRA5O99rH                             living kills
# 11  14odOyOQXtdHrNYSmdur3K                       I dunno the genre.
# 12  5jkFyQsJ8jhLSl3DmrijeV                                 OLD SOUL
# 13  5O9NC6Dy43fYpRWTA4Xs08          OLDIES MY MUM MADE ME LISTEN TO
# 14  7cxcALLQ3a5F24Eu4buWXm                                        .
# 15  4mXKyPg4EClGp4dAfOpjpt                                     👨🏾‍🍳
# 16  7zwRgcyP3veX2y47AwPwdF                                Dancehall
# 17  0awEPiA0aFgxX1tKFfGBHU                                 Pieces 🤲
# 18  3b7LTAivH87OR9hThQTJNZ                              Mapensss ❤️
# 19  3PtqtwGZW5JaUvPrkdb20f                                    Vibes
# 20  4mqXoBqLlq1YdNbCR48niw                                        🔌
# 21  2XtWFaCOyBe08DX5SvNRFF              Givēon, Brent & Frank Ocean
# 22  1M5NJfrcs5zqat3IzX0bU8                                      R&B
# 23  1JQd4Hrc6vZGaHV1zZ5pdf
# 24  7Lf3L4R2OznOwqhj8Vf0mB                          Dark rnb vibes
#
#                         owner_id  tracks  public
# 0      43rd4xexolpiac081m1ngw5ue       1    True
# 1   31bmg3cyhhncej2e5cslrcljrfru    1175    True
# 2      43rd4xexolpiac081m1ngw5ue      41   False
# 3      43rd4xexolpiac081m1ngw5ue     152    True
# 4   31newdriwnkh6m3tcnmstspsst7m     161    True
# 5      ja3t9dn7t7dou8nru1xqbkurq     201    True
# 6   31newdriwnkh6m3tcnmstspsst7m      36    True
# 7   31newdriwnkh6m3tcnmstspsst7m      33    True
# 8      43rd4xexolpiac081m1ngw5ue      25    True
# 9      m4j6zyi8888xgn3a3piqo06fd     330    True
# 10                  develdmanfam     110    True
# 11     43rd4xexolpiac081m1ngw5ue       6   False
# 12     43rd4xexolpiac081m1ngw5ue      64    True
# 13     43rd4xexolpiac081m1ngw5ue      60   False
# 14     43rd4xexolpiac081m1ngw5ue      35    True
# 15  31newdriwnkh6m3tcnmstspsst7m      32    True
# 16  31newdriwnkh6m3tcnmstspsst7m      64    True
# 17  31newdriwnkh6m3tcnmstspsst7m      61    True
# 18  3154mukloeices2kl2q4hs6ezjvy      68    True
# 19     43rd4xexolpiac081m1ngw5ue     136   False
# 20  31newdriwnkh6m3tcnmstspsst7m      94    True
# 21  31newdriwnkh6m3tcnmstspsst7m      94    True
# 22  31newdriwnkh6m3tcnmstspsst7m      84    True
# 23     vg4a1wl4kcpe93lsh6r4sjli2      61    True
# 24     ja3t9dn7t7dou8nru1xqbkurq     121    True
# ['id', 'name', 'owner_id', 'tracks', 'public']
#             tracks
# count    25.000000
# mean    129.800000
# std     228.996907
# min       1.000000
# 25%      36.000000
# 50%      64.000000
# 75%     121.000000
# max    1175.000000
#          count unique                        top freq
# id          25     25     6Pg4aEjusdmupnIU3lwaTh    1
# name        25     25           Muhiki Wa Mikosi    1
# owner_id    25      8  43rd4xexolpiac081m1ngw5ue    9

# %% [markdown]
# The playlists dataframe has a total of 5 columns

# %%
 # Checking for duplicates and null values
display(playlists.isnull().sum())
display(playlists.nunique())
# Out:
# id          0
# name        0
# owner_id    0
# tracks      0
# public      0
# dtype: int64
# id          25
# name        25
# owner_id     8
# tracks      22
# public       2
# dtype: int64

# %%
 # Top Artists
display(top_artists)
print(top_artists.columns.to_list())
display(top_artists.describe())
display(top_artists.describe(include = object).T)
# Out:
#     record_id                      id                      name  popularity  \
# 0           1  20wkVLutqVOYrc0kxFs7rA             Daniel Caesar          86
# 1           3  6kmDosYCYjFQtywDq0DLPZ                   Khamari          61
# 2           4  3tlXnStJ1fFhdScmQeLpuG              Brent Faiyaz          84
# 3           5  1Xyo4u8uXC1ZmMpatF05PJ                The Weeknd          97
# 4           6  2YZyLoL8N0Wb9xBt1NhZWg            Kendrick Lamar          95
# 5           7  2h93pZq0e7k5yf4dywlkpM               Frank Ocean          88
# 6           8  6aaMZ3fcfLv4tEbmY7bjRM             Isaiah Rashad          70
# 7           9  4V8LLVI7PbaPR0K2TGSxFF        Tyler, The Creator          90
# 8          10  1peoXq0RPx7czVoFjloeDQ                      MAVI          58
# 9          11  3QTDHixorJelOLxoxcjqGx                       SiR          68
# 10         12  5K4W6rqBFWDnAN6FQUkS6x                Kanye West          93
# 11         13  3TVXtAsR1Inumwj472S9r4                     Drake          98
# 12         14  2ICR2m4hOBPhaYiZB3rnLW                    Sonder          73
# 13         15  57vWImR43h4CaDao012Ofp                Steve Lacy          81
# 14         16  1grN0519h2zYqpRtYbDZAl                Larry June          70
# 15         17  1ybINI1qPiFbwDXamRtwxD                     Smino          68
# 16         18  4fpwOzxFRMVGfd197dKIdY               Boldy James          63
# 17         19  6l3HvQ5sa6mXTsMTB19rO5                   J. Cole          86
# 18         20  2QsynagSdAqZj3U9HgDzjD  Bob Marley & The Wailers          84
# 19         21  0eVyjRhzZKke2KFYTcDkeu             The Alchemist          72
# 20         41  20wkVLutqVOYrc0kxFs7rA             Daniel Caesar          86
# 21         42  1grN0519h2zYqpRtYbDZAl                Larry June          70
# 22         43  6l3HvQ5sa6mXTsMTB19rO5                   J. Cole          86
# 23         44  3QTDHixorJelOLxoxcjqGx                       SiR          68
# 24         45  1peoXq0RPx7czVoFjloeDQ                      MAVI          59
# 25         46  6aaMZ3fcfLv4tEbmY7bjRM             Isaiah Rashad          70
# 26         47  0Y4inQK6OespitzD6ijMwb             Freddie Gibbs          69
# 27         48  3tlXnStJ1fFhdScmQeLpuG              Brent Faiyaz          84
# 28         49  1ybINI1qPiFbwDXamRtwxD                     Smino          69
# 29         50  4MCBfE4596Uoi2O4DtmEMz                Juice WRLD          89
# 30         51  2QsynagSdAqZj3U9HgDzjD  Bob Marley & The Wailers          84
# 31         52  3ETLPQkcEd7z4k3IbZmXMq                  Cleo Sol          69
# 32         53  3qnGvpP8Yth1AqSBMqON5x              Leon Bridges          76
# 33         54  4fpwOzxFRMVGfd197dKIdY               Boldy James          63
# 34         55  2YZyLoL8N0Wb9xBt1NhZWg            Kendrick Lamar          95
# 35         56  0eVyjRhzZKke2KFYTcDkeu             The Alchemist          72
# 36         57  6X8WdFjrNhXATMDSs26aCc                  Curren$y          64
# 37         58  1wlzPS1hSNrkriIIwLFTmU                      MIKE          59
# 38         59  4V8LLVI7PbaPR0K2TGSxFF        Tyler, The Creator          90
# 39         60  57vWImR43h4CaDao012Ofp                Steve Lacy          81
# 40         61  20wkVLutqVOYrc0kxFs7rA             Daniel Caesar          86
# 41         62  6l3HvQ5sa6mXTsMTB19rO5                   J. Cole          86
# 42         63  1grN0519h2zYqpRtYbDZAl                Larry June          72
# 43         64  3QTDHixorJelOLxoxcjqGx                       SiR          68
# 44         65  4fpwOzxFRMVGfd197dKIdY               Boldy James          64
# 45         66  3tlXnStJ1fFhdScmQeLpuG              Brent Faiyaz          84
# 46         67  2YZyLoL8N0Wb9xBt1NhZWg            Kendrick Lamar          94
# 47         68  4LLpKhyESsyAXpc4laK94U                Mac Miller          85
# 48         69  0Y4inQK6OespitzD6ijMwb             Freddie Gibbs          72
# 49         70  3ETLPQkcEd7z4k3IbZmXMq                  Cleo Sol          68
# 50         71  1peoXq0RPx7czVoFjloeDQ                      MAVI          59
# 51         72  2h93pZq0e7k5yf4dywlkpM               Frank Ocean          88
# 52         73  1ybINI1qPiFbwDXamRtwxD                     Smino          68
# 53         74  6aaMZ3fcfLv4tEbmY7bjRM             Isaiah Rashad          70
# 54         75  2ICR2m4hOBPhaYiZB3rnLW                    Sonder          74
# 55         76  57vWImR43h4CaDao012Ofp                Steve Lacy          81
# 56         77  2efrqekWSHlvhATD50AG3m                 Orion Sun          60
# 57         78  4MCBfE4596Uoi2O4DtmEMz                Juice WRLD          89
# 58         79  4V8LLVI7PbaPR0K2TGSxFF        Tyler, The Creator          93
# 59         80  360IAlyVv4PCEVjgyMZrxK                    Miguel          81
#
#     followers                 genre        date
# 0     9762288              no_genre  2025-06-29
# 1      231215             indie r&b  2025-06-29
# 2     7543733                   r&b  2025-06-29
# 3   107168869              no_genre  2025-06-29
# 4    42364128               hip hop  2025-06-29
# 5    19244665              no_genre  2025-06-29
# 6     1577916              no_genre  2025-06-29
# 7    22673513              no_genre  2025-06-29
# 8      236066  experimental hip hop  2025-06-29
# 9     1147300       alternative r&b  2025-06-29
# 10   30296586                   rap  2025-06-29
# 11   99631493                   rap  2025-06-29
# 12    1865249              dark r&b  2025-06-29
# 13    6075031              no_genre  2025-06-29
# 14     520553              no_genre  2025-06-29
# 15    1037917              no_genre  2025-06-29
# 16     292340              boom bap  2025-06-29
# 17   26516106                   rap  2025-06-29
# 18   13194107                reggae  2025-06-29
# 19     842890   alternative hip hop  2025-06-29
# 20    9875718              no_genre  2025-07-13
# 21     526291              no_genre  2025-07-13
# 22   26562592                   rap  2025-07-13
# 23    1150787       alternative r&b  2025-07-13
# 24     237584  experimental hip hop  2025-07-13
# 25    1580791              no_genre  2025-07-13
# 26    1402299   alternative hip hop  2025-07-13
# 27    7582059                   r&b  2025-07-13
# 28    1040560              no_genre  2025-07-13
# 29   41117854           melodic rap  2025-07-13
# 30   13213157                reggae  2025-07-13
# 31     951670              neo soul  2025-07-13
# 32    1871122            retro soul  2025-07-13
# 33     293986              boom bap  2025-07-13
# 34   42521467               hip hop  2025-07-13
# 35     846008   alternative hip hop  2025-07-13
# 36    1061831      southern hip hop  2025-07-13
# 37     226534  experimental hip hop  2025-07-13
# 38   22813945              no_genre  2025-07-13
# 39    6104082              no_genre  2025-07-13
# 40   10031218              no_genre  2025-07-27
# 41   26627090                   rap  2025-07-27
# 42     533071              no_genre  2025-07-27
# 43    1154434       alternative r&b  2025-07-27
# 44     296053              boom bap  2025-07-27
# 45    7620033                   r&b  2025-07-27
# 46   42807187               hip hop  2025-07-27
# 47   11950245              no_genre  2025-07-27
# 48    1421586   alternative hip hop  2025-07-27
# 49     958317              neo soul  2025-07-27
# 50     238846  experimental hip hop  2025-07-27
# 51   19468634              no_genre  2025-07-27
# 52    1042664              no_genre  2025-07-27
# 53    1584005              no_genre  2025-07-27
# 54    1912330              dark r&b  2025-07-27
# 55    6138955              no_genre  2025-07-27
# 56     410217       alternative r&b  2025-07-27
# 57   41304861           melodic rap  2025-07-27
# 58   23115006              no_genre  2025-07-27
# 59    5971521                   r&b  2025-07-27
# ['record_id', 'id', 'name', 'popularity', 'followers', 'genre', 'date']
#        record_id  popularity     followers
# count  60.000000   60.000000  6.000000e+01
# mean   44.150000   77.166667  1.296314e+07
# std    25.409744   11.403488  2.125511e+07
# min     1.000000   58.000000  2.265340e+05
# 25%    16.750000   68.000000  9.566552e+05
# 50%    50.500000   75.000000  1.891726e+06
# 75%    65.250000   86.000000  1.930066e+07
# max    80.000000   98.000000  1.071689e+08
#       count unique                     top freq
# id       60     29  20wkVLutqVOYrc0kxFs7rA    3
# name     60     29           Daniel Caesar    3
# genre    60     15                no_genre   22
# date     60      3              2025-06-29   20

# %%
 # Checking for duplicates and null values
display(top_artists.isnull().sum())
display(top_artists.nunique())
# Out:
# record_id     0
# id            0
# name          0
# popularity    0
# followers     0
# genre         0
# date          0
# dtype: int64
# record_id     60
# id            29
# name          29
# popularity    25
# followers     60
# genre         15
# date           3
# dtype: int64

# %%
 # TopTracks 
display(top_tracks)
print(top_tracks.columns.to_list())
display(top_tracks.describe())
display(top_tracks.describe(include = object).T)
# Out:
#     record_id                      id  \
# 0           1  0kAy9nius3LMRVcE3W0I9J
# 1           2  0y56rCLTldeTurCf3LugTZ
# 2           3  2J6OF7CkpdQGSfm1wdclqn
# 3           4  2mzM4Y0Rnx2BDZqRnhQ5Q6
# 4           5  2uP6t2J5MEwhr9rDkAAzwh
# 5           6  5jTIePmUbBUVjJnpZeGiM3
# 6           7  6UOruoEj8UAA9iEtjbjJra
# 7           8  0Gt4nGWoATcQFL38a1NRao
# 8           9  40ZUYrNTx4WAWN39VkrCOW
# 9          10  4DQttwipnILl88cru3BRZx
# 10         11  5rgy6ghBq1eRApCkeUdJXf
# 11         12  6BrMEbPSSj55nQhkgf6DnE
# 12         13  5XUuMp2i5ojqcDOSusChqL
# 13         14  6MtStOzbbrBAEJUgLeYkIg
# 14         15  0LH7ijaQi0ybY6Oe4SCLo1
# 15         16  1Lhwn4PqeGpM4LTVUowW76
# 16         17  1p1b9LdLJ0REuFJX9mYtFX
# 17         18  2f86Ae3R4OKAu1lEIqouih
# 18         19  3u25dhBZ80h0TFewO29Wqb
# 19         20  40OaGnIeyyDFjCnqF5jb2c
# 20         41  3hhbDnFUb2bicI2df6VurK
# 21         42  2mzM4Y0Rnx2BDZqRnhQ5Q6
# 22         43  71BWZa1liIRyUiuJ3MB66o
# 23         44  5nAXbVukFLJ2Wd795L1kwS
# 24         45  5sesHCQziHg85y8dlnNWJC
# 25         46  0y56rCLTldeTurCf3LugTZ
# 26         47  1xHwJuDNzkqER4YseTBECi
# 27         48  3v6oMGduetl7GA67POX9Dm
# 28         49  5WjTrSEmsfIC1WDwIquuwT
# 29         50  40ZUYrNTx4WAWN39VkrCOW
# 30         51  1K6oXSGIexEyNnv2cS6vKr
# 31         52  2J6OF7CkpdQGSfm1wdclqn
# 32         53  2mTafy44LQJDqBqcgrtBJ0
# 33         54  4DQttwipnILl88cru3BRZx
# 34         55  4s76r7AbquJcTccqJiqdVu
# 35         56  6qUkNMd34rjpDP5EUy9JNS
# 36         57  65GbQI9VDTs7vo6MJL2iJA
# 37         58  6MtStOzbbrBAEJUgLeYkIg
# 38         59  2R4AlwtrrkMaRKojcTIzmL
# 39         60  2uP6t2J5MEwhr9rDkAAzwh
#
#                                                  name      artist_name  \
# 0                                     Right My Wrongs          Khamari
# 1                                       Head in a Jar          Khamari
# 2                                             Clouded     Brent Faiyaz
# 3                                           Free Mind             Tems
# 4                          Get You (feat. Kali Uchis)    Daniel Caesar
# 5                                        We Find Love    Daniel Caesar
# 6                                          Sweet Blue         Cleo Sol
# 7                           West Savannah (feat. SZA)    Isaiah Rashad
# 8                                            Stay Tru           Mereba
# 9                                         Night Nurse   Gregory Isaacs
# 10                 We Are Young (feat. Janelle Monáe)             fun.
# 11  Please, Please, Please, Let Me Get What I Want...       The Smiths
# 12                                          Ocho Rios    Daniel Caesar
# 13                                          DO BETTER          Ab-Soul
# 14                                 Watering My Plants       Larry June
# 15                                  You Rock My World  Michael Jackson
# 16                                               1985    Freddie Gibbs
# 17                   To Summer, From Cole - Audio Hug    Summer Walker
# 18                                   Cant Satisfy Her          I Wayne
# 19                                 No Laughing Matter      Boldy James
# 20                                              River     Leon Bridges
# 21                                          Free Mind             Tems
# 22                                         I Know You     Faye Webster
# 23                                 HARD KNOCK LULLABY         Noah Guy
# 24                   Shame (feat. BJ The Chicago Kid)    Freddie Gibbs
# 25                                      Head in a Jar          Khamari
# 26                                            New Sky              SiR
# 27                             Too Deep for the Intro          J. Cole
# 28                                                raw            LOONY
# 29                                           Stay Tru           Mereba
# 30             Transform (feat. Charlotte Day Wilson)    Daniel Caesar
# 31                                            Clouded     Brent Faiyaz
# 32                               Margie's Candy House       Larry June
# 33                                        Night Nurse   Gregory Isaacs
# 34                                       Hold Me Down    Daniel Caesar
# 35                                     Love, of Money             MAVI
# 36                                        Coming Home     Leon Bridges
# 37                                          DO BETTER          Ab-Soul
# 38                                 For the First Time      Mac DeMarco
# 39                         Get You (feat. Kali Uchis)    Daniel Caesar
#
#                  artist_id                      album_name  \
# 0   6kmDosYCYjFQtywDq0DLPZ                 A Brief Nirvana
# 1   6kmDosYCYjFQtywDq0DLPZ                   Head in a Jar
# 2   3tlXnStJ1fFhdScmQeLpuG                  Fuck The World
# 3   687cZJR45JO7jhk1LHIbgq                 For Broken Ears
# 4   20wkVLutqVOYrc0kxFs7rA                        Freudian
# 5   20wkVLutqVOYrc0kxFs7rA                        Freudian
# 6   3ETLPQkcEd7z4k3IbZmXMq                      Sweet Blue
# 7   6aaMZ3fcfLv4tEbmY7bjRM                     Cilvia Demo
# 8   294lNTPZfdqyzt8qnxmFiL  The Jungle Is The Only Way Out
# 9   6QHu71f8LLeT8n0GzfbYFc  Night Nurse (Expanded Edition)
# 10  5nCi3BB41mBaMH9gfr6Su0                     Some Nights
# 11  3yY2gUcIsjMr8hjo51PoJ8                Hatful of Hollow
# 12  20wkVLutqVOYrc0kxFs7rA                    NEVER ENOUGH
# 13  0g9vAlRPK9Gt3FKCekk4TW                         HERBERT
# 14  1grN0519h2zYqpRtYbDZAl              Adjust To The Game
# 15  3fMbdgg4jU18AjLCKBhRSm                      Invincible
# 16  0Y4inQK6OespitzD6ijMwb                         Alfredo
# 17  57LYzLEk2LcFghVwuWbcuS           CLEAR 2: SOFT LIFE EP
# 18  3HQIkVkhoARQMb0XlvyUKL                     Lava Ground
# 19  4fpwOzxFRMVGfd197dKIdY                  Super Tecmo Bo
# 20  3qnGvpP8Yth1AqSBMqON5x            Coming Home (Deluxe)
# 21  687cZJR45JO7jhk1LHIbgq                 For Broken Ears
# 22  5szilpXHcwOqnyKLqGco5j                    Faye Webster
# 23  0Cj5PLNNGVOsXUig1ic4s5              HARD KNOCK LULLABY
# 24  0Y4inQK6OespitzD6ijMwb                          Piñata
# 25  6kmDosYCYjFQtywDq0DLPZ                   Head in a Jar
# 26  3QTDHixorJelOLxoxcjqGx                  Chasing Summer
# 27  6l3HvQ5sa6mXTsMTB19rO5             Friday Night Lights
# 28  0xSfdfhcXN6T8M5gt7VwK0                      soft thing
# 29  294lNTPZfdqyzt8qnxmFiL  The Jungle Is The Only Way Out
# 30  20wkVLutqVOYrc0kxFs7rA                        Freudian
# 31  3tlXnStJ1fFhdScmQeLpuG                  Fuck The World
# 32  1grN0519h2zYqpRtYbDZAl                The Great Escape
# 33  6QHu71f8LLeT8n0GzfbYFc  Night Nurse (Expanded Edition)
# 34  20wkVLutqVOYrc0kxFs7rA                        Freudian
# 35  1peoXq0RPx7czVoFjloeDQ                Let the Sun Talk
# 36  3qnGvpP8Yth1AqSBMqON5x            Coming Home (Deluxe)
# 37  0g9vAlRPK9Gt3FKCekk4TW                         HERBERT
# 38  3Sz7ZnJQBIHsXLUSo0OQtM                    This Old Dog
# 39  20wkVLutqVOYrc0kxFs7rA                        Freudian
#
#                   album_id  duration  explicit  popularity        date
# 0   01bSLjnn8QGscvuDqccWFd    140960     False          54  2025-06-29
# 1   75JRyqkCNN6DQRdT5et7I3    196451     False          71  2025-06-29
# 2   3vi20DRHkqv4HyVg9Rt9wC    110128      True          79  2025-06-29
# 3   2sU8ByeYc5BOBFNDr58CGV    247578     False          77  2025-06-29
# 4   4E1XUBMTpLO7GpBzUo65Jp    278179     False          87  2025-06-29
# 5   4E1XUBMTpLO7GpBzUo65Jp    254919     False          76  2025-06-29
# 6   2id5Rs8ZSBGpiykreLASis    253527     False          61  2025-06-29
# 7   6JF49ixyHmOgS0Rsda2k42    167276      True          70  2025-06-29
# 8   40L9yPrh6yD1ECI3ofNfPc    237853      True          59  2025-06-29
# 9   2HEXjNNUSOwBmhyaEXG5yx    249533     False          72  2025-06-29
# 10  7m7F7SQ3BXvIpvOgjW51Gp    250626     False          82  2025-06-29
# 11  1j57Q5ntVi7crpibb0h4sv    112706     False          79  2025-06-29
# 12  7ivbFszr1TbVadj89BIy1y    153171     False          64  2025-06-29
# 13  1hNzs6WR8UbUsAkyr4jXEO    231888      True          63  2025-06-29
# 14  1fhJxvLoBB7tdxQVZhBpfB    135789      True          63  2025-06-29
# 15  52E4RP7XDzalpIrOgSTgiQ    337733     False          74  2025-06-29
# 16  3znl1qe13kyjQv7KcR685N    152546      True          65  2025-06-29
# 17  034Q9kY3buGcizT3Xpj9Re    147666      True          70  2025-06-29
# 18  7uReTXgsiJdTHdn42KO2Qp    221866     False          63  2025-06-29
# 19  5leBUcbk6qAb5cDHYuVwBO    125946      True          52  2025-06-29
# 20  21KIagsx1ZvYcv0sVkEAWv    240200     False          80  2025-07-13
# 21  2sU8ByeYc5BOBFNDr58CGV    247578     False          77  2025-07-13
# 22  0pEHMpnX1jA44pzhW3n0JB    251666     False          81  2025-07-13
# 23  5CFfxh1P809UmJeeezyeFV    153600     False          54  2025-07-13
# 24  43uErencdmuTRFZPG3zXL1    183320      True          57  2025-07-13
# 25  75JRyqkCNN6DQRdT5et7I3    196451     False          70  2025-07-13
# 26  7mU7c3lx4jCFocOYEc2rs7    191973      True          58  2025-07-13
# 27  4ghGEhWzY5ffry2IqgrnRg    225247      True          64  2025-07-13
# 28  4fVrjnFFBoVV4OEc5fBH1J    186432      True          53  2025-07-13
# 29  40L9yPrh6yD1ECI3ofNfPc    237853      True          59  2025-07-13
# 30  4E1XUBMTpLO7GpBzUo65Jp    280586     False          75  2025-07-13
# 31  3vi20DRHkqv4HyVg9Rt9wC    110128      True          78  2025-07-13
# 32  1AJrpzYu5KAbDSvmyiIUhr    165946      True          53  2025-07-13
# 33  2HEXjNNUSOwBmhyaEXG5yx    249533     False          72  2025-07-13
# 34  4E1XUBMTpLO7GpBzUo65Jp    231267     False          83  2025-07-13
# 35  1uEHrNStg2h7UMMWHKzg43     64765      True          60  2025-07-13
# 36  21KIagsx1ZvYcv0sVkEAWv    206386     False          79  2025-07-13
# 37  1hNzs6WR8UbUsAkyr4jXEO    231888      True          63  2025-07-13
# 38  4NNq2vwTapv4fSJcrZbPH7    182306     False          85  2025-07-13
# 39  4E1XUBMTpLO7GpBzUo65Jp    278179     False          86  2025-07-13
# ['record_id', 'id', 'name', 'artist_name', 'artist_id', 'album_name', 'album_id', 'duration', 'explicit', 'popularity', 'date']
#        record_id       duration  popularity
# count  40.000000      40.000000   40.000000
# mean   30.500000  203041.125000   69.200000
# std    21.079824   58639.153019   10.392798
# min     1.000000   64765.000000   52.000000
# 25%    10.750000  153492.750000   60.750000
# 50%    30.500000  214126.000000   70.000000
# 75%    50.250000  248066.750000   78.250000
# max    60.000000  337733.000000   87.000000
#             count unique                     top freq
# id             40     33  0y56rCLTldeTurCf3LugTZ    2
# name           40     33           Head in a Jar    2
# artist_name    40     25           Daniel Caesar    6
# artist_id      40     25  20wkVLutqVOYrc0kxFs7rA    6
# album_name     40     29                Freudian    5
# album_id       40     29  4E1XUBMTpLO7GpBzUo65Jp    5
# date           40      2              2025-06-29   20

# %% [markdown]
# From the top tracks database there are 11 columns

# %%
 # Checking for duplicates and null values
display(top_tracks.isnull().sum())
display(top_tracks.nunique())
# Out:
# record_id      0
# id             0
# name           0
# artist_name    0
# artist_id      0
# album_name     0
# album_id       0
# duration       0
# explicit       0
# popularity     0
# date           0
# dtype: int64
# record_id      40
# id             33
# name           33
# artist_name    25
# artist_id      25
# album_name     29
# album_id       29
# duration       33
# explicit        2
# popularity     27
# date            2
# dtype: int64

# %%
 # Recently Played tracks
display(recently_played_tracks)
print(recently_played_tracks.columns.to_list())
display(recently_played_tracks.describe())
display(recently_played_tracks.describe(include = object).T)
# Out:
#                            played_at                      id  \
# 0   2025-06-26 16:56:53.317000+00:00  6UOruoEj8UAA9iEtjbjJra
# 1   2025-06-25 10:24:38.495000+00:00  5nAXbVukFLJ2Wd795L1kwS
# 2   2025-06-25 10:21:34.883000+00:00  5pQZullzXsixizZmBcmXhy
# 3   2025-06-25 10:19:30.032000+00:00  5rgy6ghBq1eRApCkeUdJXf
# 4   2025-06-25 10:15:26.743000+00:00  0kAy9nius3LMRVcE3W0I9J
# ..                               ...                     ...
# 662 2025-07-15 18:17:50.501000+00:00  3J4Chu7wi4onjN2OO8aaow
# 663 2025-07-15 18:13:32.182000+00:00  3EWaU5exMayFzQMkIfTX7w
# 664 2025-07-15 18:11:18.922000+00:00  5qJpQEJKN2lvm0szJhyvdz
# 665 2025-07-15 18:07:05.611000+00:00  6luBKkFUt5wTwz7hpLhp12
# 666 2025-07-15 18:03:22.650000+00:00  5bfrLQFw6AB3Be3fzvY5ER
#
#                                    name      artist_name  \
# 0                            Sweet Blue         Cleo Sol
# 1                    HARD KNOCK LULLABY         Noah Guy
# 2      Freedom of Speech (with J. Cole)       Dreamville
# 3    We Are Young (feat. Janelle Monáe)             fun.
# 4                       Right My Wrongs          Khamari
# ..                                  ...              ...
# 662                        Love So Nice     Junior Kelly
# 663          either on or off the drugs        JPEGMAFIA
# 664                           Baby Girl  Cassper Nyovest
# 665                     drive ME crazy!       Lil Yachty
# 666                    Nuttin Nuh Go So            Notch
#
#                   artist_id                       album_name  \
# 0    3ETLPQkcEd7z4k3IbZmXMq                       Sweet Blue
# 1    0Cj5PLNNGVOsXUig1ic4s5               HARD KNOCK LULLABY
# 2    1iNqsUDUraNWrj00bqssQG  D-Day: A Gangsta Grillz Mixtape
# 3    5nCi3BB41mBaMH9gfr6Su0                      Some Nights
# 4    6kmDosYCYjFQtywDq0DLPZ                  A Brief Nirvana
# ..                      ...                              ...
# 662  20aXKBdnVocEWJQjDyddN9                     Love So Nice
# 663  6yJ6QQ3Y5l0s0tn7b0arrO       I LAY DOWN MY LIFE FOR YOU
# 664  18CJ8k3h2Rggioow01dlwP                            Thuto
# 665  6icQOAFXDZKsumw3YXyusw                Let’s Start Here.
# 666  5djTjSYAitkfuLplSN60gZ                   Buy Out Riddim
#
#                    album_id  duration  explicit  popularity
# 0    2id5Rs8ZSBGpiykreLASis    253527     False          61
# 1    5CFfxh1P809UmJeeezyeFV    153600     False          55
# 2    3tFjhFPqGhhLrCULnPu7Wy    131909      True          56
# 3    7m7F7SQ3BXvIpvOgjW51Gp    250626     False          82
# 4    01bSLjnn8QGscvuDqccWFd    140960     False          54
# ..                      ...       ...       ...         ...
# 662  5QG9CrByyxYglSnIhYjzP8    229280     False          51
# 663  1ezs1QD5SYQ6LtxpC9y5I2    140593      True          68
# 664  5eqTNk3knYSiqlpcUT91z7    260413      True          49
# 665  6Per97deaWqrJlKQNX8RGK    229804      True          79
# 666  3fUkJjlmkgOwtBZ7a7nPIy    242560     False          68
#
# [667 rows x 10 columns]
# ['played_at', 'id', 'name', 'artist_name', 'artist_id', 'album_name', 'album_id', 'duration', 'explicit', 'popularity']
#             duration  popularity
# count     667.000000  667.000000
# mean   205696.308846   65.403298
# std     60348.315829   13.624441
# min     51913.000000    1.000000
# 25%    169240.500000   55.000000
# 50%    208000.000000   66.000000
# 75%    240200.000000   76.000000
# max    468168.000000   93.000000
#             count unique                     top freq
# id            667    552  3hhbDnFUb2bicI2df6VurK   12
# name          667    547                   River   12
# artist_name   667    240           Daniel Caesar   30
# artist_id     667    240  20wkVLutqVOYrc0kxFs7rA   30
# album_name    667    379                Freudian   22
# album_id      667    383  4E1XUBMTpLO7GpBzUo65Jp   22

# %% [markdown]
# The recently played dataframe contains 10 columns.

# %%
 # Checking for duplicates and null values
display(recently_played_tracks.isnull().sum())
display(recently_played_tracks.nunique())
# Out:
# played_at      0
# id             0
# name           0
# artist_name    0
# artist_id      0
# album_name     0
# album_id       0
# duration       0
# explicit       0
# popularity     0
# dtype: int64
# played_at      667
# id             552
# name           547
# artist_name    240
# artist_id      240
# album_name     379
# album_id       383
# duration       547
# explicit         2
# popularity      61
# dtype: int64

# %%
 # Followed Artists
display(followed_artists)
print(followed_artists.columns.to_list())
display(followed_artists.describe())
display(followed_artists.describe(include = object).T)
# Out:
#                        id            name  popularity  followers  \
# 0  2zhossaaVN2pXg5p8o101X            Bien          58     708023
# 1  2pAWfrd7WFF3XhVt9GooDL         MF DOOM          76    3868205
# 2  6l3HvQ5sa6mXTsMTB19rO5         J. Cole          86   26516106
# 3  20wkVLutqVOYrc0kxFs7rA   Daniel Caesar          86    9762288
# 4  2h93pZq0e7k5yf4dywlkpM     Frank Ocean          88   19244665
# 5  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar          95   42364128
# 6  13ubrt8QOOCPljQ2FL1Kca      A$AP Rocky          86   16801225
# 7  1Xyo4u8uXC1ZmMpatF05PJ      The Weeknd          97  107168869
#
#                   genre
# 0             gengetone
# 1  experimental hip hop
# 2                   rap
# 3              no_genre
# 4              no_genre
# 5               hip hop
# 6                   rap
# 7              no_genre
# ['id', 'name', 'popularity', 'followers', 'genre']
#        popularity     followers
# count    8.000000  8.000000e+00
# mean    84.000000  2.830419e+07
# std     12.294017  3.451165e+07
# min     58.000000  7.080230e+05
# 25%     83.500000  8.288767e+06
# 50%     86.000000  1.802294e+07
# 75%     89.750000  3.047811e+07
# max     97.000000  1.071689e+08
#       count unique                     top freq
# id        8      8  2zhossaaVN2pXg5p8o101X    1
# name      8      8                    Bien    1
# genre     8      5                no_genre    3

# %%
 # Saved Albums
display(saved_albums)
print(saved_albums.columns.to_list())
display(saved_albums.describe())
display(saved_albums.describe(include = object).T)
# Out:
#                         id                             name     artist_name  \
# 0   3xybjP7r2VsWzwvDQipdM0                         Freudian   Daniel Caesar
# 1   0qGQrHicD7qXuz5VMlDuCe     NEVER ENOUGH (Bonus Version)   Daniel Caesar
# 2   1AJrpzYu5KAbDSvmyiIUhr                 The Great Escape      Larry June
# 3   748dZDqSZy6aPXKcI9H80u  good kid, m.A.A.d city (Deluxe)  Kendrick Lamar
# 4   7ycBtnsMtyVbbwTfJwRjSP              To Pimp A Butterfly  Kendrick Lamar
# 5   79ONNoS4M9tfIA1mYLBYVX    Mr. Morale & The Big Steppers  Kendrick Lamar
# 6   1tqKgXiDjsilZpv3aLaEGm       Alusa Why Are You Topless?            Bien
# 7   01bSLjnn8QGscvuDqccWFd                  A Brief Nirvana         Khamari
# 8   0P3oVJBFOv3TDXlYRhGL7s        Beauty Behind The Madness      The Weeknd
# 9   3Yko2SxDk4hc6fncIBQlcM              A Seat at the Table         Solange
# 10  4rA6i9oXyMhh77pqK0cXKv          Process (Bonus Edition)          Sampha
# 11  1crhG7YecAj6ZN0AAYMYsb                      CARE FOR ME            Saba
# 12  6tkjU4Umpo79wwkgPMV3nZ          Goodbye & Good Riddance      Juice WRLD
# 13  3CCnGldVQ90c26aFATC1PW                 4 Your Eyez Only         J. Cole
# 14  5wtE5aLX5r7jOosmPhJhhk                         Swimming      Mac Miller
# 15  4o5dzQHDzmBBc4Z3jSWVR9                 Rose in the Dark        Cleo Sol
# 16  4sb0eMpDn3upAFfyi4q2rw    Kind Of Blue (Legacy Edition)     Miles Davis
# 17  6TQ8nqw43uUOWu7Yqp58ko             The House Is Burning   Isaiah Rashad
# 18  3rGKeVhGWOwBzodSU6zBXQ                        shadowbox            MAVI
# 19  4ghGEhWzY5ffry2IqgrnRg              Friday Night Lights         J. Cole
# 20  21KIagsx1ZvYcv0sVkEAWv             Coming Home (Deluxe)    Leon Bridges
#
#                  artist_id  tracks  popularity
# 0   20wkVLutqVOYrc0kxFs7rA      10          50
# 1   20wkVLutqVOYrc0kxFs7rA      18          72
# 2   1grN0519h2zYqpRtYbDZAl      15          64
# 3   2YZyLoL8N0Wb9xBt1NhZWg      17          73
# 4   2YZyLoL8N0Wb9xBt1NhZWg      16          80
# 5   2YZyLoL8N0Wb9xBt1NhZWg      19          83
# 6   2zhossaaVN2pXg5p8o101X      16          55
# 7   6kmDosYCYjFQtywDq0DLPZ      11          65
# 8   1Xyo4u8uXC1ZmMpatF05PJ      14          86
# 9   2auiVi8sUZo17dLy1HwrTU      21          62
# 10  2WoVwexZuODvclzULjPQtm      12          54
# 11  7Hjbimq43OgxaBRpFXic4x      10          55
# 12  4MCBfE4596Uoi2O4DtmEMz      17          86
# 13  6l3HvQ5sa6mXTsMTB19rO5      10          74
# 14  4LLpKhyESsyAXpc4laK94U      13          80
# 15  3ETLPQkcEd7z4k3IbZmXMq      11          67
# 16  0kbYTNQb4Pb1rPbbaF0pT4      21          64
# 17  6aaMZ3fcfLv4tEbmY7bjRM      16          69
# 18  1peoXq0RPx7czVoFjloeDQ      14          56
# 19  6l3HvQ5sa6mXTsMTB19rO5      19          63
# 20  3qnGvpP8Yth1AqSBMqON5x      15          76
# ['id', 'name', 'artist_name', 'artist_id', 'tracks', 'popularity']
#           tracks  popularity
# count  21.000000   21.000000
# mean   15.000000   68.285714
# std     3.507136   10.968787
# min    10.000000   50.000000
# 25%    12.000000   62.000000
# 50%    15.000000   67.000000
# 75%    17.000000   76.000000
# max    21.000000   86.000000
#             count unique                     top freq
# id             21     21  3xybjP7r2VsWzwvDQipdM0    1
# name           21     21                Freudian    1
# artist_name    21     17          Kendrick Lamar    3
# artist_id      21     17  2YZyLoL8N0Wb9xBt1NhZWg    3

# %% [markdown]
# The saved albums have a total of 6 columns.

# %%
 # Checking for duplicates and null values
display(saved_albums.isnull().sum())
display(saved_albums.nunique())
# Out:
# id             0
# name           0
# artist_name    0
# artist_id      0
# tracks         0
# popularity     0
# dtype: int64
# id             21
# name           21
# artist_name    17
# artist_id      17
# tracks         11
# popularity     17
# dtype: int64
